# %% [markdown]
# <a href="https://colab.research.google.com/github/irandah/AI-repo/blob/development/Python_basic_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This is a python program
"""
This program start with print Welcome AI
define variable and print
do a mathamatics operation
end
"""
print("Welcome AI")

x=5
y="Hi Iranda"
print(x)
print(y)

num1=5
num2=4
print(num1*num2)
# Out:
# Welcome AI
# 5
# Hi Iranda
# 20

# %%
print("My Monthly Budget")
# Define the income
income=100000
# define the expence
food=20000
transport=12000
entertainment=8000
other=18000
# calculate saving
saving=(income-food-transport-entertainment-other)
print("Monthly saving :", saving)

# %%
print("Monthly Budget Calculator")
#Define the income
income = float(input("Enter your monthly income: "))
#Define the expence
food = float(input("Enter your monthly food expenses: "))
transport = float(input("Enter your monthly transport expenses: "))
entertainment = float(input("Enter your monthly entertainment expenses: "))
other = float(input("Enter your other monthly expenses: "))
#Calculate the expenses
total_expenses = food + transport + entertainment + other
#Calculate the Saving
savings = income - total_expenses
# Print the Budget
print("\n--- Budget Summary ---")
print(f"Income:        ${income:.2f}")
print(f"Food:          ${food:.2f}")
print(f"Transport:     ${transport:.2f}")
print(f"Entertainment: ${entertainment:.2f}")
print(f"Other:         ${other:.2f}")
print(f"Total Expenses:${total_expenses:.2f}")
print(f"Savings:       ${savings:.2f}")

if savings >0:
  print("You have saved this month !")
elif savings ==0:
 print("You have spent all wht you earn for this month !")
else:
  print("You have spent more than your income for this month !")
# Out:
# Monthly Budget Calculator
# Enter your monthly income: 3444324
# Enter your monthly food expenses: 3444444
# Enter your monthly transport expenses: 34434444
# Enter your monthly entertainment expenses: 3443434343
# Enter your other monthly expenses: 34434444
#
# --- Budget Summary ---
# Income:        $3444324.00
# Food:          $3444444.00
# Transport:     $34434444.00
# Entertainment: $3443434343.00
# Other:         $34434444.00
# Total Expenses:$3515747675.00
# Savings:       $-3512303351.00
# You have spent more than your income for this month !

# %%
#Define the age
age = int(input("Enter your age: "))
#Check voting eligible base on age
if age >=18:
  print("You are eligible for vote!")
else:
  print("You don't have voting power")
# Out:
# Enter your age: 15
# You don't have voting power
